# %%
import pandas as pd
from pathlib import Path

language = "english"
dataset = "test"
align_path = Path(f"../Data/alignments/{language}/{dataset}_boundaries.csv")
align_df = pd.read_csv(align_path)

phonetic_transcriptions = align_df["phones"].tolist()
print(f"Total phonetic transcriptions: {len(phonetic_transcriptions)}")
print(phonetic_transcriptions)
unique_set = set(phonetic_transcriptions)
print(f"Number of unique phonetic transcriptions: {len(unique_set)}")
# Out:
# Total phonetic transcriptions: 52385
# 0                 ay
# 1        b,ih,l,iy,v
# 2                 ay
# 3            hh,ae,v
# 4                 ah
#             ...
# 52380      d,eh,r,iy
# 52381         d,ao,r
# 52382    m,ih,s,t,er
# 52383    aa,t,l,iy,z
# 52384    ih,n,d,iy,d
# Name: phones, Length: 52385, dtype: object
# Number of unique phonetic transcriptions: 8184

# %%
from pathlib import Path
import textgrids
import re
from intervaltree import Interval

language = "english"
dataset = "dev"
align_dir = Path.home() / "Desktop" / "Data/Librispeech" / dataset / "alignments"
align_files = list(align_dir.glob("**/*.TextGrid"))

def _get_tier(tg, candidates):
    for name in candidates:
        if name in tg.keys():
            return tg[name]
    raise KeyError(f"None of the tiers {candidates} found in TextGrid.")

def _clean_phone(label: str) -> str:
    return re.sub(r"\d+", "", label).replace("\n", "").strip().lower()

def _overlap(a_start, a_end, b_start, b_end) -> bool:
    return not (a_end <= b_start or b_end <= a_start)

gold_fragments = []
for align_file in Path(align_dir).glob("**/*.TextGrid"):
    speaker = align_file.stem
    tg = textgrids.TextGrid(str(align_file))

    word_tier = _get_tier(tg, ["words", "word", "Words", "Word"])
    phone_tier = _get_tier(tg, ["phones", "phone", "Phones", "Phone"])

    words = [
        (w.xmin, w.xmax, w.text.strip())
        for w in word_tier
        if w.text and w.text.strip() not in {"", "<unk>"}
    ]
    raw_phones = [
        (p.xmin, p.xmax, _clean_phone(p.text))
        for p in phone_tier
        if p.text and p.text.strip() not in {"", "sil", "sp", "spn"}
    ]

    raw_phones.sort(key=lambda x: x[0])

    p_idx = 0
    n_phones = len(raw_phones)
    for w_start, w_end, w_text in words:
        while p_idx < n_phones and raw_phones[p_idx][1] <= w_start:
            p_idx += 1

        k = p_idx
        ph_seq = []
        while k < n_phones and raw_phones[k][0] < w_end:
            p_start, p_end, p_lbl = raw_phones[k]
            if _overlap(w_start, w_end, p_start, p_end):
                ph_seq.append(p_lbl)
            k += 1

        if ph_seq:
            gold_fragments.append(
                (speaker, Interval(w_start, w_end, (w_text,  "-".join(ph_seq))))
            )

print(f"Total gold fragments: {len(gold_fragments)}, Example: {gold_fragments[0]}")
# Out:
# Total gold fragments: 54402, Example: ('6313-66125-0015', Interval(0.2, 0.71, ('cautiously', 'k-ao-sh-ah-s-l-iy')))

# %%
align_type = "phones"
clustering_dict = {}
for speaker, interval in gold_fragments:
    word, ph_seq = interval.data
    if ph_seq not in clustering_dict:
        clustering_dict[ph_seq] = []
    clustering_dict[ph_seq].append((speaker, interval))

partition_file = Path(f"Data/partitions/{language}/{dataset}_{align_type}_partition.txt")
partition_file.parent.mkdir(parents=True, exist_ok=True)
with open(partition_file, "w") as f:
    id_nmr = 0
    for cluster_id in clustering_dict:
        f.write(f"Class {id_nmr}\n")
        entries = clustering_dict[cluster_id]
        for speaker, interval in entries:
            word, ph_seq = interval.data
            f.write(
                f"{speaker} {interval.begin:.3f} {interval.end:.3f} {word} {ph_seq}\n"
            )
        f.write("\n")
        id_nmr += 1

# %%
from utils.evaluate_partition import evaluate_partition_file
evaluate_partition_file(partition_file, language, dataset, f"GT-{align_type}", runtime=0)
# Out:
# Number of gold fragments: 54252
# Building trees: 100%|██████████| 54252/54252 [00:00<00:00, 82085.35it/s]
# 54252 == 54252
# Example transcription: (0, '6313-66125-0015', Interval(0.18, 0.73), ['k', 'ao', 'sh', 'ah', 's', 'l', 'iy'], 'cautiously')
#
# ===== Summary =====
# Language         : english
# Dataset          : dev
# Model            : GT-phones
#
# --- Evaluation Metrics ---
# NED              : 0.0%
# Purity*          : 98.0%
# Completeness*    : 91.2%
# Homogeinity      : 99.3%
# Completeness     : 97.4%
# V-measure        : 98.4%
# Bitrate          : 33.5 bits/s
#
# --- Clustering ---
# Predicted clusters: 8358
# True number types : 8216
# Difference        : 142
#
# --- Runtime ---
# Total runtime (s): 0.00
#
# --- Parameters ---

# %%
import editdistance
import itertools
from collections import Counter

def distance(seq1, seq2):
    return editdistance.eval(seq1.split("-"), seq2.split("-")) / max(len(seq1.split("-")), len(seq2.split("-")))

for cluster_id in clustering_dict:
    entries = clustering_dict[cluster_id]

    distances = []
    for (speaker1, interval1), (speaker2, interval2) in itertools.combinations(entries, 2):
        word1, ph_seq1 = interval1.data
        word2, ph_seq2 = interval2.data
        dist = distance(ph_seq1, ph_seq2)
        distances.append(dist)
    
    if distances:
        avg_distance = sum(distances) / len(distances)
        if avg_distance == 0:
            continue

        print(f"Cluster: {cluster_id} [length: {len(entries)}], NED = {avg_distance*100:.3f}%")

        # --- Count and show unique phone sequence proportions ---
        ph_seq_counts = Counter([interval.data[1] for _, interval in entries])
        total = sum(ph_seq_counts.values())

        print("Phonetic variants and proportions:")
        for ph_seq, count in ph_seq_counts.items():
            proportion = count / total * 100
            print(f"- {ph_seq} ({count}/{total}, {proportion:.1f}%)")

        print("-" * 50)
# Out:
# Cluster: a [length: 1198], NED = 11.893%
# Phonetic variants and proportions:
# - ah (1122/1198, 93.7%)
# - ey (76/1198, 6.3%)
# --------------------------------------------------
# Cluster: the [length: 3448], NED = 15.230%
# Phonetic variants and proportions:
# - dh-ah (2802/3448, 81.3%)
# - dh-iy (646/3448, 18.7%)
# --------------------------------------------------
# Cluster: to [length: 1378], NED = 32.853%
# Phonetic variants and proportions:
# - t-ah (565/1378, 41.0%)
# - t-ih (441/1378, 32.0%)
# - t-uw (372/1378, 27.0%)
# --------------------------------------------------
# Cluster: that [length: 642], NED = 16.687%
# Phonetic variants and proportions:
# - dh-ae-t (327/642, 50.9%)
# - dh-ah-t (315/642, 49.1%)
# --------------------------------------------------
# Cluster: us [length: 67], NED = 2.239%
# Phonetic variants and proportions:
# - ah-s (66/67, 98.5%)
# - y-uw-eh-s (1/67, 1.5%)
# --------------------------------------------------
# Cluster: can [length: 62], NED = 8.408%
# Phonetic variants and proportions:
# - k-ah-n (53/62, 85.5%)
# - k-ae-n (9/62, 14.5%)
# --------------------------------------------------
# Cluster: was [length: 684], NED = 4.170%
# Phonetic variants and proportions:
# - w-ah-z (639/684, 93.4%)
# - w-ao-z (29/684, 4.2%)
# - w-aa-z (16/684, 2.3%)
# --------------------------------------------------
# Cluster: on [length: 323], NED = 19.597%
# Phonetic variants and proportions:
# - ao-n (86/323, 26.6%)
# - aa-n (237/323, 73.4%)
# --------------------------------------------------
# Cluster: doesn't [length: 7], NED = 7.937%
# Phonetic variants and proportions:
# - d-ah-z-ah-n-t (2/7, 28.6%)
# - d-ah-z-ah-n (5/7, 71.4%)
# --------------------------------------------------
# Cluster: him [length: 221], NED = 8.507%
# Phonetic variants and proportions:
# - hh-ih-m (188/221, 85.1%)
# - ih-m (33/221, 14.9%)
# --------------------------------------------------
# Cluster: and [length: 1915], NED = 15.285%
# Phonetic variants and proportions:
# - ae-n-d (1234/1915, 64.4%)
# - ah-n-d (681/1915, 35.6%)
# --------------------------------------------------
# Cluster: when [length: 162], NED = 21.266%
# Phonetic variants and proportions:
# - hh-w-ih-n (8/162, 4.9%)
# - w-ih-n (24/162, 14.8%)
# - w-eh-n (71/162, 43.8%)
# - hh-w-eh-n (59/162, 36.4%)
# --------------------------------------------------
# Cluster: from [length: 215], NED = 19.352%
# Phonetic variants and proportions:
# - f-er-m (159/215, 74.0%)
# - f-r-ah-m (56/215, 26.0%)
# --------------------------------------------------
# Cluster: as [length: 421], NED = 24.177%
# Phonetic variants and proportions:
# - eh-z (250/421, 59.4%)
# - ae-z (171/421, 40.6%)
# --------------------------------------------------
# Cluster: between [length: 29], NED = 7.389%
# Phonetic variants and proportions:
# - b-ih-t-w-iy-n (20/29, 69.0%)
# - b-iy-t-w-iy-n (9/29, 31.0%)
# --------------------------------------------------
# Cluster: them [length: 167], NED = 15.550%
# Phonetic variants and proportions:
# - dh-ah-m (61/167, 36.5%)
# - dh-eh-m (106/167, 63.5%)
# --------------------------------------------------
# Cluster: below [length: 8], NED = 6.250%
# Phonetic variants and proportions:
# - b-ih-l-ow (7/8, 87.5%)
# - b-iy-l-ow (1/8, 12.5%)
# --------------------------------------------------
# Cluster: enough [length: 32], NED = 5.645%
# Phonetic variants and proportions:
# - ih-n-ah-f (28/32, 87.5%)
# - iy-n-ah-f (4/32, 12.5%)
# --------------------------------------------------
# Cluster: don't [length: 38], NED = 11.949%
# Phonetic variants and proportions:
# - d-ow-n-t (24/38, 63.2%)
# - d-ow-n (14/38, 36.8%)
# --------------------------------------------------
# Cluster: what [length: 138], NED = 10.211%
# Phonetic variants and proportions:
# - w-ah-t (99/138, 71.7%)
# - hh-w-ah-t (39/138, 28.3%)
# --------------------------------------------------
# Cluster: hours [length: 13], NED = 12.821%
# Phonetic variants and proportions:
# - aw-er-z (10/13, 76.9%)
# - aw-r-z (3/13, 23.1%)
# --------------------------------------------------
# Cluster: ears [length: 9], NED = 16.667%
# Phonetic variants and proportions:
# - iy-r-z (6/9, 66.7%)
# - ih-r-z (3/9, 33.3%)
# --------------------------------------------------
# Cluster: are [length: 168], NED = 49.843%
# Phonetic variants and proportions:
# - er (92/168, 54.8%)
# - aa-r (76/168, 45.2%)
# --------------------------------------------------
# Cluster: does [length: 16], NED = 10.833%
# Phonetic variants and proportions:
# - d-ah-z (13/16, 81.2%)
# - d-ih-z (3/16, 18.8%)
# --------------------------------------------------
# Cluster: before [length: 65], NED = 9.750%
# Phonetic variants and proportions:
# - b-ih-f-ao-r (39/65, 60.0%)
# - b-iy-f-ao-r (26/65, 40.0%)
# --------------------------------------------------
# Cluster: around [length: 15], NED = 10.476%
# Phonetic variants and proportions:
# - er-aw-n-d (11/15, 73.3%)
# - er-aw-n (4/15, 26.7%)
# --------------------------------------------------
# Cluster: perfectly [length: 7], NED = 5.952%
# Phonetic variants and proportions:
# - p-er-f-ah-k-t-l-iy (2/7, 28.6%)
# - p-er-f-ah-k-l-iy (5/7, 71.4%)
# --------------------------------------------------
# Cluster: asked [length: 29], NED = 11.700%
# Phonetic variants and proportions:
# - ae-s-t (19/29, 65.5%)
# - ae-s-k-t (10/29, 34.5%)
# --------------------------------------------------
# Cluster: hands [length: 23], NED = 10.277%
# Phonetic variants and proportions:
# - hh-ae-n-d-z (13/23, 56.5%)
# - hh-ae-n-z (10/23, 43.5%)
# --------------------------------------------------
# Cluster: protest [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - p-r-ow-t-eh-s-t (1/2, 50.0%)
# - p-r-ah-t-eh-s-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: shouted [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - sh-aw-t-ah-d (1/2, 50.0%)
# - sh-aw-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: am [length: 35], NED = 28.011%
# Phonetic variants and proportions:
# - ae-m (25/35, 71.4%)
# - ey-eh-m (10/35, 28.6%)
# --------------------------------------------------
# Cluster: one [length: 219], NED = 7.786%
# Phonetic variants and proportions:
# - w-ah-n (177/219, 80.8%)
# - hh-w-ah-n (42/219, 19.2%)
# --------------------------------------------------
# Cluster: has [length: 64], NED = 16.518%
# Phonetic variants and proportions:
# - hh-ah-z (27/64, 42.2%)
# - hh-ae-z (37/64, 57.8%)
# --------------------------------------------------
# Cluster: result [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - r-iy-z-ah-l-t (2/3, 66.7%)
# - r-ih-z-ah-l-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: kept [length: 18], NED = 9.150%
# Phonetic variants and proportions:
# - k-eh-p-t (14/18, 77.8%)
# - k-ae-p-t (4/18, 22.2%)
# --------------------------------------------------
# Cluster: going [length: 36], NED = 8.889%
# Phonetic variants and proportions:
# - g-ow-ih-ng (28/36, 77.8%)
# - g-ow-ih-n (8/36, 22.2%)
# --------------------------------------------------
# Cluster: with [length: 470], NED = 10.689%
# Phonetic variants and proportions:
# - w-ih-dh (94/470, 20.0%)
# - w-ih-th (376/470, 80.0%)
# --------------------------------------------------
# Cluster: surprise [length: 5], NED = 6.667%
# Phonetic variants and proportions:
# - s-ah-p-r-ay-z (4/5, 80.0%)
# - s-er-p-r-ay-z (1/5, 20.0%)
# --------------------------------------------------
# Cluster: for [length: 401], NED = 31.217%
# Phonetic variants and proportions:
# - f-r-er (159/401, 39.7%)
# - f-er (168/401, 41.9%)
# - f-ao-r (74/401, 18.5%)
# --------------------------------------------------
# Cluster: into [length: 140], NED = 12.220%
# Phonetic variants and proportions:
# - ih-n-t-ah (58/140, 41.4%)
# - ih-n-t-uw (82/140, 58.6%)
# --------------------------------------------------
# Cluster: which [length: 223], NED = 10.465%
# Phonetic variants and proportions:
# - w-ih-ch (157/223, 70.4%)
# - hh-w-ih-ch (66/223, 29.6%)
# --------------------------------------------------
# Cluster: been [length: 155], NED = 10.473%
# Phonetic variants and proportions:
# - b-ih-n (125/155, 80.6%)
# - b-ah-n (30/155, 19.4%)
# --------------------------------------------------
# Cluster: fire [length: 27], NED = 17.094%
# Phonetic variants and proportions:
# - f-ay-er (15/27, 55.6%)
# - f-ay-r (12/27, 44.4%)
# --------------------------------------------------
# Cluster: within [length: 16], NED = 8.000%
# Phonetic variants and proportions:
# - w-ih-th-ih-n (12/16, 75.0%)
# - w-ih-dh-ih-n (4/16, 25.0%)
# --------------------------------------------------
# Cluster: an [length: 149], NED = 15.781%
# Phonetic variants and proportions:
# - ah-n (120/149, 80.5%)
# - ae-n (29/149, 19.5%)
# --------------------------------------------------
# Cluster: every [length: 63], NED = 3.021%
# Phonetic variants and proportions:
# - eh-v-r-iy (59/63, 93.7%)
# - eh-v-er-iy (4/63, 6.3%)
# --------------------------------------------------
# Cluster: walk [length: 11], NED = 18.182%
# Phonetic variants and proportions:
# - w-ao-k (5/11, 45.5%)
# - w-aa-k (6/11, 54.5%)
# --------------------------------------------------
# Cluster: close [length: 15], NED = 10.476%
# Phonetic variants and proportions:
# - k-l-ow-s (11/15, 73.3%)
# - k-l-ow-z (4/15, 26.7%)
# --------------------------------------------------
# Cluster: couldn't [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - k-uh-d-ah-n (2/3, 66.7%)
# - k-uh-d-ah-n-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: get [length: 36], NED = 16.931%
# Phonetic variants and proportions:
# - g-ih-t (20/36, 55.6%)
# - g-eh-t (16/36, 44.4%)
# --------------------------------------------------
# Cluster: why [length: 20], NED = 17.544%
# Phonetic variants and proportions:
# - hh-w-ay (10/20, 50.0%)
# - w-ay (10/20, 50.0%)
# --------------------------------------------------
# Cluster: most [length: 58], NED = 7.260%
# Phonetic variants and proportions:
# - m-ow-s-t (48/58, 82.8%)
# - m-ow-s (10/58, 17.2%)
# --------------------------------------------------
# Cluster: last [length: 50], NED = 14.633%
# Phonetic variants and proportions:
# - l-ae-s (18/50, 36.0%)
# - l-ae-s-t (29/50, 58.0%)
# - l-ao-s-t (3/50, 6.0%)
# --------------------------------------------------
# Cluster: during [length: 10], NED = 21.333%
# Phonetic variants and proportions:
# - d-er-ih-ng (2/10, 20.0%)
# - d-y-uh-r-ih-ng (6/10, 60.0%)
# - d-uh-r-ih-ng (2/10, 20.0%)
# --------------------------------------------------
# Cluster: spirit [length: 11], NED = 9.091%
# Phonetic variants and proportions:
# - s-p-ih-r-ah-t (6/11, 54.5%)
# - s-p-ih-r-ih-t (5/11, 45.5%)
# --------------------------------------------------
# Cluster: themselves [length: 30], NED = 0.833%
# Phonetic variants and proportions:
# - dh-ah-m-s-eh-l-v-z (29/30, 96.7%)
# - dh-eh-m-s-eh-l-v-z (1/30, 3.3%)
# --------------------------------------------------
# Cluster: just [length: 41], NED = 9.451%
# Phonetic variants and proportions:
# - jh-ah-s-t (31/41, 75.6%)
# - jh-ih-s-t (10/41, 24.4%)
# --------------------------------------------------
# Cluster: what's [length: 5], NED = 12.000%
# Phonetic variants and proportions:
# - hh-w-ah-t-s (3/5, 60.0%)
# - w-ah-t-s (2/5, 40.0%)
# --------------------------------------------------
# Cluster: demanded [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - d-ih-m-ae-n-d-ih-d (1/2, 50.0%)
# - d-ih-m-ae-n-d-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: while [length: 50], NED = 12.020%
# Phonetic variants and proportions:
# - hh-w-ay-l (31/50, 62.0%)
# - w-ay-l (19/50, 38.0%)
# --------------------------------------------------
# Cluster: sunday [length: 8], NED = 5.000%
# Phonetic variants and proportions:
# - s-ah-n-d-iy (1/8, 12.5%)
# - s-ah-n-d-ey (7/8, 87.5%)
# --------------------------------------------------
# Cluster: president [length: 3], NED = 14.815%
# Phonetic variants and proportions:
# - p-r-eh-z-ih-d-ah-n-t (1/3, 33.3%)
# - p-r-eh-z-ah-d-eh-n-t (2/3, 66.7%)
# --------------------------------------------------
# Cluster: will [length: 114], NED = 12.757%
# Phonetic variants and proportions:
# - w-ah-l (85/114, 74.6%)
# - w-ih-l (29/114, 25.4%)
# --------------------------------------------------
# Cluster: without [length: 49], NED = 10.102%
# Phonetic variants and proportions:
# - w-ih-th-aw-t (27/49, 55.1%)
# - w-ih-dh-aw-t (22/49, 44.9%)
# --------------------------------------------------
# Cluster: fall [length: 13], NED = 17.949%
# Phonetic variants and proportions:
# - f-aa-l (7/13, 53.8%)
# - f-ao-l (6/13, 46.2%)
# --------------------------------------------------
# Cluster: gentlemen [length: 7], NED = 5.291%
# Phonetic variants and proportions:
# - jh-eh-n-t-ah-l-m-ih-n (2/7, 28.6%)
# - jh-eh-n-ah-l-m-ih-n (5/7, 71.4%)
# --------------------------------------------------
# Cluster: toward [length: 11], NED = 16.970%
# Phonetic variants and proportions:
# - t-ah-w-ao-r-d (4/11, 36.4%)
# - t-ao-r-d (7/11, 63.6%)
# --------------------------------------------------
# Cluster: duty [length: 9], NED = 10.000%
# Phonetic variants and proportions:
# - d-y-uw-t-iy (3/9, 33.3%)
# - d-uw-t-iy (6/9, 66.7%)
# --------------------------------------------------
# Cluster: morrow [length: 10], NED = 11.667%
# Phonetic variants and proportions:
# - m-aa-r-ow (7/10, 70.0%)
# - m-ao-r-ow (3/10, 30.0%)
# --------------------------------------------------
# Cluster: wrangler [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - r-ae-ng-g-l-er (2/3, 66.7%)
# - r-ae-ng-g-ah-l-er (1/3, 33.3%)
# --------------------------------------------------
# Cluster: second [length: 23], NED = 7.378%
# Phonetic variants and proportions:
# - s-eh-k-ah-n (16/23, 69.6%)
# - s-eh-k-ah-n-d (7/23, 30.4%)
# --------------------------------------------------
# Cluster: isn't [length: 7], NED = 9.524%
# Phonetic variants and proportions:
# - ih-z-ah-n-t (5/7, 71.4%)
# - ih-z-ah-n (2/7, 28.6%)
# --------------------------------------------------
# Cluster: horses [length: 9], NED = 9.259%
# Phonetic variants and proportions:
# - hh-ao-r-s-ih-z (5/9, 55.6%)
# - hh-ao-r-s-ah-z (4/9, 44.4%)
# --------------------------------------------------
# Cluster: or [length: 207], NED = 48.075%
# Phonetic variants and proportions:
# - er (82/207, 39.6%)
# - ao-r (125/207, 60.4%)
# --------------------------------------------------
# Cluster: hour [length: 22], NED = 24.242%
# Phonetic variants and proportions:
# - aw-er (14/22, 63.6%)
# - aw-r (8/22, 36.4%)
# --------------------------------------------------
# Cluster: where [length: 47], NED = 12.766%
# Phonetic variants and proportions:
# - hh-w-eh-r (23/47, 48.9%)
# - w-eh-r (24/47, 51.1%)
# --------------------------------------------------
# Cluster: sounds [length: 5], NED = 12.000%
# Phonetic variants and proportions:
# - s-aw-n-d-z (2/5, 40.0%)
# - s-aw-n-z (3/5, 60.0%)
# --------------------------------------------------
# Cluster: law [length: 10], NED = 23.333%
# Phonetic variants and proportions:
# - l-ao (7/10, 70.0%)
# - l-aa (3/10, 30.0%)
# --------------------------------------------------
# Cluster: received [length: 13], NED = 8.547%
# Phonetic variants and proportions:
# - r-ah-s-iy-v-d (2/13, 15.4%)
# - r-ih-s-iy-v-d (9/13, 69.2%)
# - r-iy-s-iy-v-d (2/13, 15.4%)
# --------------------------------------------------
# Cluster: egypt [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - iy-jh-ih-p-t (2/3, 66.7%)
# - iy-jh-ah-p-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: vanity [length: 8], NED = 4.167%
# Phonetic variants and proportions:
# - v-ae-n-ah-t-iy (7/8, 87.5%)
# - v-ae-n-ih-t-iy (1/8, 12.5%)
# --------------------------------------------------
# Cluster: friends [length: 20], NED = 7.368%
# Phonetic variants and proportions:
# - f-r-eh-n-d-z (6/20, 30.0%)
# - f-r-eh-n-z (14/20, 70.0%)
# --------------------------------------------------
# Cluster: than [length: 86], NED = 6.320%
# Phonetic variants and proportions:
# - dh-ah-n (77/86, 89.5%)
# - dh-ae-n (9/86, 10.5%)
# --------------------------------------------------
# Cluster: savages [length: 3], NED = 19.048%
# Phonetic variants and proportions:
# - s-ae-v-ah-jh-ah-z (2/3, 66.7%)
# - s-ae-v-ih-jh-ih-z (1/3, 33.3%)
# --------------------------------------------------
# Cluster: christians [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - k-r-ih-s-ch-ih-n-z (2/3, 66.7%)
# - k-r-ih-s-ch-ah-n-z (1/3, 33.3%)
# --------------------------------------------------
# Cluster: twenty [length: 15], NED = 8.889%
# Phonetic variants and proportions:
# - t-w-eh-n-t-iy (7/15, 46.7%)
# - t-w-eh-n-iy (8/15, 53.3%)
# --------------------------------------------------
# Cluster: cause [length: 12], NED = 17.677%
# Phonetic variants and proportions:
# - k-aa-z (7/12, 58.3%)
# - k-ao-z (5/12, 41.7%)
# --------------------------------------------------
# Cluster: return [length: 7], NED = 11.429%
# Phonetic variants and proportions:
# - r-ih-t-er-n (4/7, 57.1%)
# - r-iy-t-er-n (3/7, 42.9%)
# --------------------------------------------------
# Cluster: your [length: 61], NED = 10.710%
# Phonetic variants and proportions:
# - y-ao-r (12/61, 19.7%)
# - y-uh-r (49/61, 80.3%)
# --------------------------------------------------
# Cluster: limits [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - l-ih-m-ih-t-s (1/2, 50.0%)
# - l-ih-m-ah-t-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: awful [length: 4], NED = 12.500%
# Phonetic variants and proportions:
# - ao-f-ah-l (3/4, 75.0%)
# - aa-f-ah-l (1/4, 25.0%)
# --------------------------------------------------
# Cluster: forgotten [length: 6], NED = 13.333%
# Phonetic variants and proportions:
# - f-er-g-aa-t-ah-n (4/6, 66.7%)
# - f-ao-r-g-aa-t-ah-n (2/6, 33.3%)
# --------------------------------------------------
# Cluster: remembered [length: 7], NED = 3.571%
# Phonetic variants and proportions:
# - r-ih-m-eh-m-b-er-d (6/7, 85.7%)
# - r-iy-m-eh-m-b-er-d (1/7, 14.3%)
# --------------------------------------------------
# Cluster: affected [length: 4], NED = 7.143%
# Phonetic variants and proportions:
# - ah-f-eh-k-t-ih-d (3/4, 75.0%)
# - ah-f-eh-k-t-ah-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: present [length: 15], NED = 5.714%
# Phonetic variants and proportions:
# - p-r-eh-z-ah-n-t (14/15, 93.3%)
# - p-er-z-eh-n-t (1/15, 6.7%)
# --------------------------------------------------
# Cluster: multitude [length: 2], NED = 11.111%
# Phonetic variants and proportions:
# - m-ah-l-t-ah-t-y-uw-d (1/2, 50.0%)
# - m-ah-l-t-ah-t-uw-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: human [length: 22], NED = 5.195%
# Phonetic variants and proportions:
# - hh-y-uw-m-ah-n (18/22, 81.8%)
# - y-uw-m-ah-n (4/22, 18.2%)
# --------------------------------------------------
# Cluster: conduct [length: 4], NED = 7.143%
# Phonetic variants and proportions:
# - k-ah-n-d-ah-k-t (1/4, 25.0%)
# - k-aa-n-d-ah-k-t (3/4, 75.0%)
# --------------------------------------------------
# Cluster: perfect [length: 10], NED = 3.333%
# Phonetic variants and proportions:
# - p-er-f-ih-k-t (9/10, 90.0%)
# - p-er-f-eh-k-t (1/10, 10.0%)
# --------------------------------------------------
# Cluster: refuse [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - r-ah-f-y-uw-z (1/2, 50.0%)
# - r-ih-f-y-uw-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: knowledge [length: 4], NED = 10.000%
# Phonetic variants and proportions:
# - n-aa-l-ih-jh (3/4, 75.0%)
# - n-aa-l-ah-jh (1/4, 25.0%)
# --------------------------------------------------
# Cluster: attribute [length: 2], NED = 25.000%
# Phonetic variants and proportions:
# - ae-t-r-ah-b-y-uw-t (1/2, 50.0%)
# - ah-t-r-ih-b-y-uw-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: selected [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - s-ah-l-eh-k-t-ih-d (1/2, 50.0%)
# - s-ah-l-eh-k-t-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: worship [length: 5], NED = 12.000%
# Phonetic variants and proportions:
# - w-er-sh-ah-p (3/5, 60.0%)
# - w-er-sh-ih-p (2/5, 40.0%)
# --------------------------------------------------
# Cluster: supreme [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - s-ah-p-r-iy-m (3/4, 75.0%)
# - s-er-p-r-iy-m (1/4, 25.0%)
# --------------------------------------------------
# Cluster: reserve [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - r-ih-z-er-v (2/3, 66.7%)
# - r-iy-z-er-v (1/3, 33.3%)
# --------------------------------------------------
# Cluster: eternity [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - ih-t-er-n-ah-t-iy (2/3, 66.7%)
# - iy-t-er-n-ah-t-iy (1/3, 33.3%)
# --------------------------------------------------
# Cluster: progress [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - p-r-aa-g-r-eh-s (2/3, 66.7%)
# - p-r-ow-g-r-eh-s (1/3, 33.3%)
# --------------------------------------------------
# Cluster: service [length: 6], NED = 6.667%
# Phonetic variants and proportions:
# - s-er-v-ah-s (5/6, 83.3%)
# - s-er-v-ih-s (1/6, 16.7%)
# --------------------------------------------------
# Cluster: hero [length: 3], NED = 16.667%
# Phonetic variants and proportions:
# - hh-iy-r-ow (2/3, 66.7%)
# - hh-ih-r-ow (1/3, 33.3%)
# --------------------------------------------------
# Cluster: humanity [length: 4], NED = 5.556%
# Phonetic variants and proportions:
# - y-uw-m-ae-n-ih-t-iy (1/4, 25.0%)
# - hh-y-uw-m-ae-n-ih-t-iy (3/4, 75.0%)
# --------------------------------------------------
# Cluster: hundred [length: 17], NED = 21.008%
# Phonetic variants and proportions:
# - hh-ah-n-d-er-d (4/17, 23.5%)
# - hh-ah-n-er-d (3/17, 17.6%)
# - hh-ah-n-d-r-ah-d (8/17, 47.1%)
# - hh-ah-n-d-r-ih-d (2/17, 11.8%)
# --------------------------------------------------
# Cluster: years [length: 30], NED = 25.402%
# Phonetic variants and proportions:
# - y-ih-r-z (17/30, 56.7%)
# - y-er-z (13/30, 43.3%)
# --------------------------------------------------
# Cluster: length [length: 6], NED = 12.000%
# Phonetic variants and proportions:
# - l-eh-ng-th (3/6, 50.0%)
# - l-eh-ng-k-th (3/6, 50.0%)
# --------------------------------------------------
# Cluster: doctor [length: 12], NED = 10.909%
# Phonetic variants and proportions:
# - d-aa-k-t-er (6/12, 50.0%)
# - d-ao-k-t-er (6/12, 50.0%)
# --------------------------------------------------
# Cluster: excuse [length: 4], NED = 9.524%
# Phonetic variants and proportions:
# - ih-k-s-k-y-uw-s (2/4, 50.0%)
# - ih-k-s-k-y-uw-z (2/4, 50.0%)
# --------------------------------------------------
# Cluster: personally [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - p-er-s-ah-n-ah-l-iy (1/2, 50.0%)
# - p-er-s-ah-n-l-iy (1/2, 50.0%)
# --------------------------------------------------
# Cluster: encouraged [length: 2], NED = 28.571%
# Phonetic variants and proportions:
# - ih-n-k-er-ah-jh-d (1/2, 50.0%)
# - eh-n-k-er-ih-jh-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: either [length: 21], NED = 15.556%
# Phonetic variants and proportions:
# - ay-dh-er (14/21, 66.7%)
# - iy-dh-er (7/21, 33.3%)
# --------------------------------------------------
# Cluster: whatever [length: 11], NED = 6.234%
# Phonetic variants and proportions:
# - w-ah-t-eh-v-er (8/11, 72.7%)
# - hh-w-ah-t-eh-v-er (3/11, 27.3%)
# --------------------------------------------------
# Cluster: handed [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - hh-ae-n-d-ah-d (3/4, 75.0%)
# - hh-ae-n-d-ih-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: neither [length: 13], NED = 12.821%
# Phonetic variants and proportions:
# - n-iy-dh-er (8/13, 61.5%)
# - n-ay-dh-er (5/13, 38.5%)
# --------------------------------------------------
# Cluster: because [length: 28], NED = 3.968%
# Phonetic variants and proportions:
# - b-ih-k-ah-z (25/28, 89.3%)
# - b-ih-k-ao-z (3/28, 10.7%)
# --------------------------------------------------
# Cluster: clothes [length: 4], NED = 10.000%
# Phonetic variants and proportions:
# - k-l-ow-dh-z (1/4, 25.0%)
# - k-l-ow-z (3/4, 75.0%)
# --------------------------------------------------
# Cluster: cannot [length: 15], NED = 10.667%
# Phonetic variants and proportions:
# - k-ah-n-aa-t (7/15, 46.7%)
# - k-ae-n-aa-t (8/15, 53.3%)
# --------------------------------------------------
# Cluster: our [length: 83], NED = 23.009%
# Phonetic variants and proportions:
# - aa-r (69/83, 83.1%)
# - aw-r (6/83, 7.2%)
# - aw-er (8/83, 9.6%)
# --------------------------------------------------
# Cluster: began [length: 23], NED = 8.854%
# Phonetic variants and proportions:
# - b-iy-g-ae-n (16/23, 69.6%)
# - b-ih-g-ae-n (7/23, 30.4%)
# --------------------------------------------------
# Cluster: empty [length: 9], NED = 7.778%
# Phonetic variants and proportions:
# - eh-m-p-t-iy (7/9, 77.8%)
# - eh-m-t-iy (2/9, 22.2%)
# --------------------------------------------------
# Cluster: always [length: 30], NED = 5.747%
# Phonetic variants and proportions:
# - ao-l-w-iy-z (25/30, 83.3%)
# - ao-l-w-ey-z (5/30, 16.7%)
# --------------------------------------------------
# Cluster: trying [length: 6], NED = 6.667%
# Phonetic variants and proportions:
# - t-r-ay-ih-ng (5/6, 83.3%)
# - t-r-ay-ng (1/6, 16.7%)
# --------------------------------------------------
# Cluster: respectable [length: 3], NED = 6.061%
# Phonetic variants and proportions:
# - r-ih-s-p-eh-k-t-ah-b-ah-l (2/3, 66.7%)
# - r-iy-s-p-eh-k-t-ah-b-ah-l (1/3, 33.3%)
# --------------------------------------------------
# Cluster: family [length: 8], NED = 4.167%
# Phonetic variants and proportions:
# - f-ae-m-l-iy (7/8, 87.5%)
# - f-ae-m-ah-l-iy (1/8, 12.5%)
# --------------------------------------------------
# Cluster: enjoy [length: 7], NED = 7.143%
# Phonetic variants and proportions:
# - ih-n-jh-oy (6/7, 85.7%)
# - eh-n-jh-oy (1/7, 14.3%)
# --------------------------------------------------
# Cluster: strength [length: 13], NED = 4.029%
# Phonetic variants and proportions:
# - s-t-r-eh-ng-k-th (11/13, 84.6%)
# - s-t-r-eh-ng-th (2/13, 15.4%)
# --------------------------------------------------
# Cluster: required [length: 8], NED = 7.653%
# Phonetic variants and proportions:
# - r-iy-k-w-ay-er-d (5/8, 62.5%)
# - r-iy-k-w-ay-r-d (3/8, 37.5%)
# --------------------------------------------------
# Cluster: peculiar [length: 4], NED = 6.250%
# Phonetic variants and proportions:
# - p-ih-k-y-uw-l-y-er (3/4, 75.0%)
# - p-ah-k-y-uw-l-y-er (1/4, 25.0%)
# --------------------------------------------------
# Cluster: natural [length: 14], NED = 8.242%
# Phonetic variants and proportions:
# - n-ae-ch-r-ah-l (9/14, 64.3%)
# - n-ae-ch-er-ah-l (5/14, 35.7%)
# --------------------------------------------------
# Cluster: goodness [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - g-uh-d-n-ah-s (3/4, 75.0%)
# - g-uh-d-n-ih-s (1/4, 25.0%)
# --------------------------------------------------
# Cluster: often [length: 17], NED = 8.824%
# Phonetic variants and proportions:
# - ao-f-t-ah-n (5/17, 29.4%)
# - ao-f-ah-n (12/17, 70.6%)
# --------------------------------------------------
# Cluster: education [length: 5], NED = 13.333%
# Phonetic variants and proportions:
# - eh-jh-y-uw-k-ey-sh-ah-n (2/5, 40.0%)
# - eh-jh-ah-k-ey-sh-ah-n (3/5, 60.0%)
# --------------------------------------------------
# Cluster: good [length: 72], NED = 6.677%
# Phonetic variants and proportions:
# - g-uh-d (64/72, 88.9%)
# - g-ih-d (8/72, 11.1%)
# --------------------------------------------------
# Cluster: wants [length: 11], NED = 3.636%
# Phonetic variants and proportions:
# - w-aa-n-t-s (10/11, 90.9%)
# - w-ao-n-t-s (1/11, 9.1%)
# --------------------------------------------------
# Cluster: given [length: 16], NED = 10.000%
# Phonetic variants and proportions:
# - g-ih-v-ah-n (10/16, 62.5%)
# - g-ih-v-ih-n (6/16, 37.5%)
# --------------------------------------------------
# Cluster: general [length: 9], NED = 9.259%
# Phonetic variants and proportions:
# - jh-eh-n-er-ah-l (5/9, 55.6%)
# - jh-eh-n-r-ah-l (4/9, 44.4%)
# --------------------------------------------------
# Cluster: whether [length: 12], NED = 8.182%
# Phonetic variants and proportions:
# - hh-w-eh-dh-er (3/12, 25.0%)
# - w-eh-dh-er (9/12, 75.0%)
# --------------------------------------------------
# Cluster: question [length: 13], NED = 13.187%
# Phonetic variants and proportions:
# - k-w-eh-sh-ah-n (4/13, 30.8%)
# - k-w-eh-s-ch-ah-n (9/13, 69.2%)
# --------------------------------------------------
# Cluster: effect [length: 10], NED = 10.222%
# Phonetic variants and proportions:
# - ah-f-eh-k-t (7/10, 70.0%)
# - ih-f-eh-k-t (2/10, 20.0%)
# - iy-f-eh-k-t (1/10, 10.0%)
# --------------------------------------------------
# Cluster: circumstances [length: 7], NED = 4.762%
# Phonetic variants and proportions:
# - s-er-k-ah-m-s-t-ae-n-s-ih-z (4/7, 57.1%)
# - s-er-k-ah-m-s-t-ae-n-s-ah-z (3/7, 42.9%)
# --------------------------------------------------
# Cluster: read [length: 9], NED = 16.667%
# Phonetic variants and proportions:
# - r-eh-d (6/9, 66.7%)
# - r-iy-d (3/9, 33.3%)
# --------------------------------------------------
# Cluster: whenever [length: 6], NED = 8.571%
# Phonetic variants and proportions:
# - hh-w-eh-n-eh-v-er (3/6, 50.0%)
# - w-eh-n-eh-v-er (3/6, 50.0%)
# --------------------------------------------------
# Cluster: preserve [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - p-r-ah-z-er-v (1/2, 50.0%)
# - p-r-ih-z-er-v (1/2, 50.0%)
# --------------------------------------------------
# Cluster: coffee [length: 2], NED = 25.000%
# Phonetic variants and proportions:
# - k-ao-f-iy (1/2, 50.0%)
# - k-aa-f-iy (1/2, 50.0%)
# --------------------------------------------------
# Cluster: pointed [length: 3], NED = 22.222%
# Phonetic variants and proportions:
# - p-oy-n-ah-d (1/3, 33.3%)
# - p-oy-n-t-ah-d (1/3, 33.3%)
# - p-oy-n-t-ih-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: seventy [length: 5], NED = 5.714%
# Phonetic variants and proportions:
# - s-eh-v-ah-n-t-iy (1/5, 20.0%)
# - s-eh-v-ah-n-iy (4/5, 80.0%)
# --------------------------------------------------
# Cluster: due [length: 5], NED = 20.000%
# Phonetic variants and proportions:
# - d-uw (3/5, 60.0%)
# - d-y-uw (2/5, 40.0%)
# --------------------------------------------------
# Cluster: prisoners [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - p-r-ih-z-ah-n-er-z (2/4, 50.0%)
# - p-r-ih-z-n-er-z (2/4, 50.0%)
# --------------------------------------------------
# Cluster: returned [length: 15], NED = 7.937%
# Phonetic variants and proportions:
# - r-iy-t-er-n-d (10/15, 66.7%)
# - r-ih-t-er-n-d (5/15, 33.3%)
# --------------------------------------------------
# Cluster: remain [length: 6], NED = 6.667%
# Phonetic variants and proportions:
# - r-iy-m-ey-n (1/6, 16.7%)
# - r-ih-m-ey-n (5/6, 83.3%)
# --------------------------------------------------
# Cluster: entered [length: 13], NED = 3.077%
# Phonetic variants and proportions:
# - eh-n-t-er-d (12/13, 92.3%)
# - eh-n-er-d (1/13, 7.7%)
# --------------------------------------------------
# Cluster: religious [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - r-iy-l-ih-jh-ah-s (2/3, 66.7%)
# - r-ih-l-ih-jh-ah-s (1/3, 33.3%)
# --------------------------------------------------
# Cluster: prayer [length: 3], NED = 33.333%
# Phonetic variants and proportions:
# - p-r-ey-er (1/3, 33.3%)
# - p-r-eh-r (2/3, 66.7%)
# --------------------------------------------------
# Cluster: eternal [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - ih-t-er-n-ah-l (3/5, 60.0%)
# - iy-t-er-n-ah-l (2/5, 40.0%)
# --------------------------------------------------
# Cluster: epoch [length: 2], NED = 25.000%
# Phonetic variants and proportions:
# - iy-p-ah-k (1/2, 50.0%)
# - eh-p-ah-k (1/2, 50.0%)
# --------------------------------------------------
# Cluster: christian [length: 8], NED = 6.122%
# Phonetic variants and proportions:
# - k-r-ih-s-ch-ah-n (6/8, 75.0%)
# - k-r-ih-s-ch-ih-n (2/8, 25.0%)
# --------------------------------------------------
# Cluster: soft [length: 7], NED = 14.286%
# Phonetic variants and proportions:
# - s-ao-f-t (4/7, 57.1%)
# - s-aa-f-t (3/7, 42.9%)
# --------------------------------------------------
# Cluster: remained [length: 10], NED = 7.778%
# Phonetic variants and proportions:
# - r-ih-m-ey-n-d (7/10, 70.0%)
# - r-iy-m-ey-n-d (3/10, 30.0%)
# --------------------------------------------------
# Cluster: white [length: 28], NED = 1.786%
# Phonetic variants and proportions:
# - w-ay-t (27/28, 96.4%)
# - hh-w-ay-t (1/28, 3.6%)
# --------------------------------------------------
# Cluster: savage [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - s-ae-v-ah-jh (1/3, 33.3%)
# - s-ae-v-ih-jh (2/3, 66.7%)
# --------------------------------------------------
# Cluster: gifts [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - g-ih-f-s (1/2, 50.0%)
# - g-ih-f-t-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: several [length: 18], NED = 3.486%
# Phonetic variants and proportions:
# - s-eh-v-r-ah-l (16/18, 88.9%)
# - s-eh-v-er-ah-l (2/18, 11.1%)
# --------------------------------------------------
# Cluster: covering [length: 4], NED = 11.111%
# Phonetic variants and proportions:
# - k-ah-v-er-ih-ng (2/4, 50.0%)
# - k-ah-v-r-ih-ng (2/4, 50.0%)
# --------------------------------------------------
# Cluster: events [length: 9], NED = 3.704%
# Phonetic variants and proportions:
# - ih-v-eh-n-t-s (8/9, 88.9%)
# - iy-v-eh-n-t-s (1/9, 11.1%)
# --------------------------------------------------
# Cluster: new [length: 42], NED = 17.034%
# Phonetic variants and proportions:
# - n-uw (22/42, 52.4%)
# - n-y-uw (20/42, 47.6%)
# --------------------------------------------------
# Cluster: beside [length: 6], NED = 10.667%
# Phonetic variants and proportions:
# - b-ih-s-ay-d (4/6, 66.7%)
# - b-iy-s-ay-d (2/6, 33.3%)
# --------------------------------------------------
# Cluster: use [length: 16], NED = 17.778%
# Phonetic variants and proportions:
# - y-uw-z (8/16, 50.0%)
# - y-uw-s (8/16, 50.0%)
# --------------------------------------------------
# Cluster: faces [length: 5], NED = 12.000%
# Phonetic variants and proportions:
# - f-ey-s-ah-z (2/5, 40.0%)
# - f-ey-s-ih-z (3/5, 60.0%)
# --------------------------------------------------
# Cluster: unit [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - y-uw-n-ih-t (1/2, 50.0%)
# - y-uw-n-ah-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: says [length: 22], NED = 3.030%
# Phonetic variants and proportions:
# - s-eh-z (21/22, 95.5%)
# - s-ih-z (1/22, 4.5%)
# --------------------------------------------------
# Cluster: grandmother [length: 5], NED = 11.389%
# Phonetic variants and proportions:
# - g-r-ae-m-ah-dh-er (1/5, 20.0%)
# - g-r-ae-n-m-ah-dh-er (2/5, 40.0%)
# - g-r-ae-n-d-m-ah-dh-er (2/5, 40.0%)
# --------------------------------------------------
# Cluster: secret [length: 10], NED = 8.889%
# Phonetic variants and proportions:
# - s-iy-k-r-ah-t (4/10, 40.0%)
# - s-iy-k-r-ih-t (6/10, 60.0%)
# --------------------------------------------------
# Cluster: founded [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - f-aw-n-d-ah-d (1/2, 50.0%)
# - f-aw-n-d-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: became [length: 16], NED = 10.000%
# Phonetic variants and proportions:
# - b-ih-k-ey-m (6/16, 37.5%)
# - b-iy-k-ey-m (10/16, 62.5%)
# --------------------------------------------------
# Cluster: enormous [length: 6], NED = 7.619%
# Phonetic variants and proportions:
# - ih-n-ao-r-m-ah-s (4/6, 66.7%)
# - ih-n-ao-r-m-ih-s (2/6, 33.3%)
# --------------------------------------------------
# Cluster: excited [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - ih-k-s-ay-t-ih-d (2/3, 66.7%)
# - ih-k-s-ay-t-ah-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: really [length: 9], NED = 12.500%
# Phonetic variants and proportions:
# - r-ih-l-iy (6/9, 66.7%)
# - r-iy-l-iy (3/9, 33.3%)
# --------------------------------------------------
# Cluster: suggested [length: 4], NED = 5.556%
# Phonetic variants and proportions:
# - s-ah-g-jh-eh-s-t-ah-d (3/4, 75.0%)
# - s-ah-g-jh-eh-s-t-ih-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: prisoner [length: 5], NED = 5.714%
# Phonetic variants and proportions:
# - p-r-ih-z-ah-n-er (1/5, 20.0%)
# - p-r-ih-z-n-er (4/5, 80.0%)
# --------------------------------------------------
# Cluster: started [length: 11], NED = 6.234%
# Phonetic variants and proportions:
# - s-t-aa-r-t-ah-d (3/11, 27.3%)
# - s-t-aa-r-t-ih-d (8/11, 72.7%)
# --------------------------------------------------
# Cluster: added [length: 13], NED = 12.821%
# Phonetic variants and proportions:
# - ae-d-ah-d (5/13, 38.5%)
# - ae-d-ih-d (8/13, 61.5%)
# --------------------------------------------------
# Cluster: remark [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - r-ih-m-aa-r-k (2/3, 66.7%)
# - r-iy-m-aa-r-k (1/3, 33.3%)
# --------------------------------------------------
# Cluster: alexander [length: 10], NED = 5.185%
# Phonetic variants and proportions:
# - ae-l-ah-g-z-ae-n-d-er (7/10, 70.0%)
# - ae-l-ih-g-z-ae-n-d-er (3/10, 30.0%)
# --------------------------------------------------
# Cluster: prevented [length: 4], NED = 7.407%
# Phonetic variants and proportions:
# - p-r-ih-v-eh-n-ih-d (2/4, 50.0%)
# - p-r-ih-v-eh-n-t-ih-d (2/4, 50.0%)
# --------------------------------------------------
# Cluster: softly [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - s-ao-f-l-iy (3/5, 60.0%)
# - s-ao-f-t-l-iy (2/5, 40.0%)
# --------------------------------------------------
# Cluster: gets [length: 2], NED = 25.000%
# Phonetic variants and proportions:
# - g-ih-t-s (1/2, 50.0%)
# - g-eh-t-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: satisfied [length: 6], NED = 4.167%
# Phonetic variants and proportions:
# - s-ae-t-ah-s-f-ay-d (5/6, 83.3%)
# - s-ae-t-ih-s-f-ay-d (1/6, 16.7%)
# --------------------------------------------------
# Cluster: knew [length: 30], NED = 17.165%
# Phonetic variants and proportions:
# - n-y-uw (14/30, 46.7%)
# - n-uw (16/30, 53.3%)
# --------------------------------------------------
# Cluster: didn't [length: 4], NED = 36.667%
# Phonetic variants and proportions:
# - d-ih-d-ah-n (2/4, 50.0%)
# - d-ih-d-n-t (1/4, 25.0%)
# - d-ih-n-t (1/4, 25.0%)
# --------------------------------------------------
# Cluster: towards [length: 12], NED = 11.688%
# Phonetic variants and proportions:
# - t-ao-r-d-z (9/12, 75.0%)
# - t-ah-w-ao-r-d-z (3/12, 25.0%)
# --------------------------------------------------
# Cluster: recall [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - r-ih-k-ao-l (1/2, 50.0%)
# - r-iy-k-ao-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: thirty [length: 9], NED = 9.722%
# Phonetic variants and proportions:
# - th-er-d-iy (7/9, 77.8%)
# - th-er-t-iy (2/9, 22.2%)
# --------------------------------------------------
# Cluster: visitor [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - v-ih-z-ih-t-er (1/3, 33.3%)
# - v-ih-z-ah-t-er (2/3, 66.7%)
# --------------------------------------------------
# Cluster: postscript [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - p-ow-s-t-s-k-r-ih-p-t (1/2, 50.0%)
# - p-ow-s-k-r-ih-p-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: probably [length: 15], NED = 10.476%
# Phonetic variants and proportions:
# - p-r-aa-b-ah-b-l-iy (11/15, 73.3%)
# - p-r-aa-b-l-iy (4/15, 26.7%)
# --------------------------------------------------
# Cluster: remember [length: 5], NED = 8.571%
# Phonetic variants and proportions:
# - r-ih-m-eh-m-b-er (3/5, 60.0%)
# - r-iy-m-eh-m-b-er (2/5, 40.0%)
# --------------------------------------------------
# Cluster: occasionally [length: 7], NED = 9.921%
# Phonetic variants and proportions:
# - ah-k-ey-zh-ah-n-ah-l-iy (3/7, 42.9%)
# - ah-k-ey-zh-n-ah-l-iy (3/7, 42.9%)
# - ah-k-ey-zh-ah-n-l-iy (1/7, 14.3%)
# --------------------------------------------------
# Cluster: rather [length: 11], NED = 12.727%
# Phonetic variants and proportions:
# - r-ae-dh-er (7/11, 63.6%)
# - r-ah-dh-er (4/11, 36.4%)
# --------------------------------------------------
# Cluster: english [length: 6], NED = 5.556%
# Phonetic variants and proportions:
# - ih-ng-g-l-ih-sh (5/6, 83.3%)
# - ih-ng-l-ih-sh (1/6, 16.7%)
# --------------------------------------------------
# Cluster: painted [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - p-ey-n-ih-d (1/2, 50.0%)
# - p-ey-n-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: surprising [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - s-er-p-r-ay-z-ih-ng (1/2, 50.0%)
# - s-ah-p-r-ay-z-ih-ng (1/2, 50.0%)
# --------------------------------------------------
# Cluster: pieces [length: 6], NED = 12.000%
# Phonetic variants and proportions:
# - p-iy-s-ih-z (3/6, 50.0%)
# - p-iy-s-ah-z (3/6, 50.0%)
# --------------------------------------------------
# Cluster: carriage [length: 4], NED = 20.000%
# Phonetic variants and proportions:
# - k-ae-r-ih-jh (1/4, 25.0%)
# - k-eh-r-ah-jh (3/4, 75.0%)
# --------------------------------------------------
# Cluster: regarded [length: 4], NED = 12.500%
# Phonetic variants and proportions:
# - r-ah-g-aa-r-d-ah-d (3/4, 75.0%)
# - r-ih-g-aa-r-d-ih-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: mosses [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - m-ao-s-ah-z (2/3, 66.7%)
# - m-ao-s-ih-z (1/3, 33.3%)
# --------------------------------------------------
# Cluster: places [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - p-l-ey-s-ah-z (2/5, 40.0%)
# - p-l-ey-s-ih-z (3/5, 60.0%)
# --------------------------------------------------
# Cluster: thousand [length: 17], NED = 8.088%
# Phonetic variants and proportions:
# - th-aw-z-ah-n-d (11/17, 64.7%)
# - th-aw-z-ah-n (6/17, 35.3%)
# --------------------------------------------------
# Cluster: history [length: 8], NED = 8.929%
# Phonetic variants and proportions:
# - hh-ih-s-t-r-iy (3/8, 37.5%)
# - hh-ih-s-t-er-iy (5/8, 62.5%)
# --------------------------------------------------
# Cluster: traveling [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - t-r-ae-v-ah-l-ih-ng (1/2, 50.0%)
# - t-r-ae-v-l-ih-ng (1/2, 50.0%)
# --------------------------------------------------
# Cluster: masses [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - m-ae-s-ah-z (1/2, 50.0%)
# - m-ae-s-ih-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: encountered [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - ih-n-k-aw-n-er-d (1/3, 33.3%)
# - ih-n-k-aw-n-t-er-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: spotted [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - s-p-aa-t-ah-d (1/2, 50.0%)
# - s-p-aa-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: needed [length: 7], NED = 9.524%
# Phonetic variants and proportions:
# - n-iy-d-ih-d (5/7, 71.4%)
# - n-iy-d-ah-d (2/7, 28.6%)
# --------------------------------------------------
# Cluster: nice [length: 6], NED = 11.111%
# Phonetic variants and proportions:
# - n-ay-s (5/6, 83.3%)
# - n-iy-s (1/6, 16.7%)
# --------------------------------------------------
# Cluster: want [length: 6], NED = 8.333%
# Phonetic variants and proportions:
# - w-aa-n-t (5/6, 83.3%)
# - w-ao-n-t (1/6, 16.7%)
# --------------------------------------------------
# Cluster: wonderfully [length: 3], NED = 7.407%
# Phonetic variants and proportions:
# - w-ah-n-d-er-f-ah-l-iy (1/3, 33.3%)
# - w-ah-n-d-er-f-l-iy (2/3, 66.7%)
# --------------------------------------------------
# Cluster: supported [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - s-ah-p-ao-r-t-ih-d (1/2, 50.0%)
# - s-ah-p-ao-r-t-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: i'm [length: 23], NED = 8.300%
# Phonetic variants and proportions:
# - ay-m (21/23, 91.3%)
# - ah-m (2/23, 8.7%)
# --------------------------------------------------
# Cluster: getting [length: 10], NED = 7.111%
# Phonetic variants and proportions:
# - g-eh-t-ih-ng (2/10, 20.0%)
# - g-ih-t-ih-ng (8/10, 80.0%)
# --------------------------------------------------
# Cluster: protect [length: 4], NED = 19.048%
# Phonetic variants and proportions:
# - p-r-ah-t-eh-k-t (2/4, 50.0%)
# - p-er-t-eh-k-t (2/4, 50.0%)
# --------------------------------------------------
# Cluster: cottage [length: 6], NED = 6.667%
# Phonetic variants and proportions:
# - k-aa-t-ah-jh (1/6, 16.7%)
# - k-aa-t-ih-jh (5/6, 83.3%)
# --------------------------------------------------
# Cluster: next [length: 13], NED = 10.769%
# Phonetic variants and proportions:
# - n-eh-k-s-t (7/13, 53.8%)
# - n-eh-k-s (6/13, 46.2%)
# --------------------------------------------------
# Cluster: courage [length: 4], NED = 12.500%
# Phonetic variants and proportions:
# - k-er-ih-jh (3/4, 75.0%)
# - k-er-ah-jh (1/4, 25.0%)
# --------------------------------------------------
# Cluster: minute [length: 11], NED = 9.091%
# Phonetic variants and proportions:
# - m-ih-n-ah-t (10/11, 90.9%)
# - m-ay-n-y-uw-t (1/11, 9.1%)
# --------------------------------------------------
# Cluster: ours [length: 7], NED = 34.921%
# Phonetic variants and proportions:
# - aa-r-z (4/7, 57.1%)
# - aw-er-z (2/7, 28.6%)
# - aw-r-z (1/7, 14.3%)
# --------------------------------------------------
# Cluster: granted [length: 2], NED = 28.571%
# Phonetic variants and proportions:
# - g-r-ae-n-ah-d (1/2, 50.0%)
# - g-r-ae-n-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: purposes [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - p-er-p-ah-s-ah-z (1/2, 50.0%)
# - p-er-p-ah-s-ih-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: live [length: 12], NED = 5.556%
# Phonetic variants and proportions:
# - l-ih-v (11/12, 91.7%)
# - l-ay-v (1/12, 8.3%)
# --------------------------------------------------
# Cluster: eclipse [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - ih-k-l-ih-p-s (1/2, 50.0%)
# - ah-k-l-ih-p-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: sacred [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - s-ey-k-r-ih-d (1/2, 50.0%)
# - s-ey-k-r-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: already [length: 16], NED = 5.417%
# Phonetic variants and proportions:
# - ao-l-r-eh-d-iy (13/16, 81.2%)
# - ao-r-eh-d-iy (3/16, 18.8%)
# --------------------------------------------------
# Cluster: related [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - r-iy-l-ey-t-ih-d (1/2, 50.0%)
# - r-ih-l-ey-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: ancient [length: 10], NED = 8.889%
# Phonetic variants and proportions:
# - ey-n-sh-ah-n-t (6/10, 60.0%)
# - ey-n-ch-ah-n-t (4/10, 40.0%)
# --------------------------------------------------
# Cluster: interview [length: 5], NED = 5.714%
# Phonetic variants and proportions:
# - ih-n-t-er-v-y-uw (4/5, 80.0%)
# - ih-n-er-v-y-uw (1/5, 20.0%)
# --------------------------------------------------
# Cluster: reply [length: 8], NED = 5.000%
# Phonetic variants and proportions:
# - r-ih-p-l-ay (7/8, 87.5%)
# - r-iy-p-l-ay (1/8, 12.5%)
# --------------------------------------------------
# Cluster: regret [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - r-ah-g-r-eh-t (3/4, 75.0%)
# - r-ih-g-r-eh-t (1/4, 25.0%)
# --------------------------------------------------
# Cluster: beyond [length: 8], NED = 10.000%
# Phonetic variants and proportions:
# - b-ih-aa-n-d (1/8, 12.5%)
# - b-iy-ao-n-d (7/8, 87.5%)
# --------------------------------------------------
# Cluster: different [length: 14], NED = 3.768%
# Phonetic variants and proportions:
# - d-ih-f-r-ah-n-t (12/14, 85.7%)
# - d-ih-f-er-ah-n-t (2/14, 14.3%)
# --------------------------------------------------
# Cluster: madame [length: 2], NED = 40.000%
# Phonetic variants and proportions:
# - m-ae-d-ah-m (1/2, 50.0%)
# - m-ah-d-ae-m (1/2, 50.0%)
# --------------------------------------------------
# Cluster: expected [length: 4], NED = 5.556%
# Phonetic variants and proportions:
# - ih-k-s-p-eh-k-t-ih-d (3/4, 75.0%)
# - ih-k-s-p-eh-k-t-ah-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: intended [length: 7], NED = 5.952%
# Phonetic variants and proportions:
# - ih-n-t-eh-n-d-ih-d (5/7, 71.4%)
# - ih-n-t-eh-n-d-ah-d (2/7, 28.6%)
# --------------------------------------------------
# Cluster: minister [length: 4], NED = 7.143%
# Phonetic variants and proportions:
# - m-ih-n-ih-s-t-er (1/4, 25.0%)
# - m-ih-n-ah-s-t-er (3/4, 75.0%)
# --------------------------------------------------
# Cluster: offices [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - ao-f-ah-s-ih-z (1/2, 50.0%)
# - ao-f-ah-s-ah-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: planted [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - p-l-ae-n-t-ih-d (1/3, 33.3%)
# - p-l-ae-n-t-ah-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: houses [length: 7], NED = 11.429%
# Phonetic variants and proportions:
# - hh-aw-s-ah-z (3/7, 42.9%)
# - hh-aw-s-ih-z (4/7, 57.1%)
# --------------------------------------------------
# Cluster: miserable [length: 5], NED = 7.500%
# Phonetic variants and proportions:
# - m-ih-z-er-ah-b-ah-l (3/5, 60.0%)
# - m-ih-z-r-ah-b-ah-l (2/5, 40.0%)
# --------------------------------------------------
# ...
# --------------------------------------------------
# Cluster: completed [length: 3], NED = 7.407%
# Phonetic variants and proportions:
# - k-ah-m-p-l-iy-t-ih-d (2/3, 66.7%)
# - k-ah-m-p-l-iy-t-ah-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: direct [length: 3], NED = 22.222%
# Phonetic variants and proportions:
# - d-er-eh-k-t (2/3, 66.7%)
# - d-ih-r-eh-k-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: cruel [length: 4], NED = 10.000%
# Phonetic variants and proportions:
# - k-r-uw-ah-l (1/4, 25.0%)
# - k-r-uw-l (3/4, 75.0%)
# --------------------------------------------------
# Cluster: surprised [length: 5], NED = 5.714%
# Phonetic variants and proportions:
# - s-ah-p-r-ay-z-d (4/5, 80.0%)
# - s-er-p-r-ay-z-d (1/5, 20.0%)
# --------------------------------------------------
# Cluster: replied [length: 8], NED = 7.143%
# Phonetic variants and proportions:
# - r-ih-p-l-ay-d (6/8, 75.0%)
# - r-iy-p-l-ay-d (2/8, 25.0%)
# --------------------------------------------------
# Cluster: visit [length: 8], NED = 5.000%
# Phonetic variants and proportions:
# - v-ih-z-ih-t (7/8, 87.5%)
# - v-ih-z-ah-t (1/8, 12.5%)
# --------------------------------------------------
# Cluster: gradually [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - g-r-ae-jh-uw-ah-l-iy (2/3, 66.7%)
# - g-r-ae-jh-uw-l-iy (1/3, 33.3%)
# --------------------------------------------------
# Cluster: suicide [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - s-uw-ah-s-ay-d (1/3, 33.3%)
# - s-uw-ih-s-ay-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: gentleman [length: 4], NED = 5.556%
# Phonetic variants and proportions:
# - jh-eh-n-t-ah-l-m-ah-n (3/4, 75.0%)
# - jh-eh-n-ah-l-m-ah-n (1/4, 25.0%)
# --------------------------------------------------
# Cluster: whip [length: 4], NED = 16.667%
# Phonetic variants and proportions:
# - w-ih-p (2/4, 50.0%)
# - hh-w-ih-p (2/4, 50.0%)
# --------------------------------------------------
# Cluster: report [length: 5], NED = 6.667%
# Phonetic variants and proportions:
# - r-ih-p-ao-r-t (4/5, 80.0%)
# - r-iy-p-ao-r-t (1/5, 20.0%)
# --------------------------------------------------
# Cluster: yours [length: 3], NED = 16.667%
# Phonetic variants and proportions:
# - y-ao-r-z (2/3, 66.7%)
# - y-uh-r-z (1/3, 33.3%)
# --------------------------------------------------
# Cluster: relieved [length: 4], NED = 11.111%
# Phonetic variants and proportions:
# - r-iy-l-iy-v-d (2/4, 50.0%)
# - r-ih-l-iy-v-d (2/4, 50.0%)
# --------------------------------------------------
# Cluster: hadn't [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - hh-ae-d-ah-n-t (2/3, 66.7%)
# - hh-ae-d-ah-n (1/3, 33.3%)
# --------------------------------------------------
# Cluster: wanted [length: 11], NED = 21.818%
# Phonetic variants and proportions:
# - w-ao-n-ih-d (3/11, 27.3%)
# - w-aa-n-t-ah-d (8/11, 72.7%)
# --------------------------------------------------
# Cluster: relief [length: 8], NED = 10.714%
# Phonetic variants and proportions:
# - r-ih-l-iy-f (3/8, 37.5%)
# - r-iy-l-iy-f (5/8, 62.5%)
# --------------------------------------------------
# Cluster: lifted [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - l-ih-f-t-ih-d (3/5, 60.0%)
# - l-ih-f-t-ah-d (2/5, 40.0%)
# --------------------------------------------------
# Cluster: color [length: 6], NED = 13.333%
# Phonetic variants and proportions:
# - k-ah-l-er (4/6, 66.7%)
# - k-ao-l-er (2/6, 33.3%)
# --------------------------------------------------
# Cluster: wherever [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - hh-w-eh-r-eh-v-er (1/2, 50.0%)
# - w-eh-r-eh-v-er (1/2, 50.0%)
# --------------------------------------------------
# Cluster: whispered [length: 8], NED = 3.571%
# Phonetic variants and proportions:
# - w-ih-s-p-er-d (7/8, 87.5%)
# - hh-w-ih-s-p-er-d (1/8, 12.5%)
# --------------------------------------------------
# Cluster: connected [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - k-ah-n-eh-k-t-ih-d (2/3, 66.7%)
# - k-ah-n-eh-k-t-ah-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: detail [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - d-iy-t-ey-l (1/2, 50.0%)
# - d-ih-t-ey-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: gospel [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - g-aa-s-p-ah-l (1/2, 50.0%)
# - g-ao-s-p-ah-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: process [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - p-r-aa-s-eh-s (1/2, 50.0%)
# - p-r-ao-s-eh-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: interesting [length: 2], NED = 11.111%
# Phonetic variants and proportions:
# - ih-n-t-r-ih-s-t-ih-ng (1/2, 50.0%)
# - ih-n-t-er-ih-s-t-ih-ng (1/2, 50.0%)
# --------------------------------------------------
# Cluster: bought [length: 4], NED = 22.222%
# Phonetic variants and proportions:
# - b-aa-t (2/4, 50.0%)
# - b-ao-t (2/4, 50.0%)
# --------------------------------------------------
# Cluster: victory [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - v-ih-k-t-er-iy (3/5, 60.0%)
# - v-ih-k-t-r-iy (2/5, 40.0%)
# --------------------------------------------------
# Cluster: lives [length: 7], NED = 14.286%
# Phonetic variants and proportions:
# - l-ih-v-z (4/7, 57.1%)
# - l-ay-v-z (3/7, 42.9%)
# --------------------------------------------------
# Cluster: loaded [length: 4], NED = 13.333%
# Phonetic variants and proportions:
# - l-ow-d-ih-d (2/4, 50.0%)
# - l-ow-d-ah-d (2/4, 50.0%)
# --------------------------------------------------
# Cluster: omitted [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - ow-m-ih-t-ah-d (1/3, 33.3%)
# - ow-m-ih-t-ih-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: essential [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - ah-s-eh-n-ch-ah-l (1/2, 50.0%)
# - iy-s-eh-n-ch-ah-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: advantage [length: 6], NED = 15.238%
# Phonetic variants and proportions:
# - ah-d-v-ae-n-t-ih-jh (4/6, 66.7%)
# - ah-d-v-ae-n-ah-jh (1/6, 16.7%)
# - ae-d-v-ae-n-ih-jh (1/6, 16.7%)
# --------------------------------------------------
# Cluster: passes [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - p-ae-s-ih-z (1/3, 33.3%)
# - p-ae-s-ah-z (2/3, 66.7%)
# --------------------------------------------------
# Cluster: whichever [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - hh-w-ih-ch-eh-v-er (1/2, 50.0%)
# - w-ih-ch-eh-v-er (1/2, 50.0%)
# --------------------------------------------------
# Cluster: ended [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - eh-n-d-ih-d (1/2, 50.0%)
# - eh-n-d-ah-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: rounded [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - r-aw-n-d-ah-d (1/2, 50.0%)
# - r-aw-n-d-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: chestnut [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - ch-eh-s-t-n-ah-t (1/2, 50.0%)
# - ch-eh-s-n-ah-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: route [length: 2], NED = 33.333%
# Phonetic variants and proportions:
# - r-aw-t (1/2, 50.0%)
# - r-uw-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: interested [length: 2], NED = 11.111%
# Phonetic variants and proportions:
# - ih-n-t-er-ih-s-t-ih-d (1/2, 50.0%)
# - ih-n-t-r-ih-s-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: inhabitants [length: 2], NED = 9.091%
# Phonetic variants and proportions:
# - ih-n-hh-ae-b-ah-t-ah-n-t-s (1/2, 50.0%)
# - ih-n-hh-ae-b-ih-t-ah-n-t-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: dollars [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - d-ao-l-er-z (1/2, 50.0%)
# - d-aa-l-er-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: adventures [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - ah-d-v-eh-n-ch-er-z (1/2, 50.0%)
# - ae-d-v-eh-n-ch-er-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: quarter [length: 5], NED = 6.667%
# Phonetic variants and proportions:
# - k-ao-r-t-er (1/5, 20.0%)
# - k-w-ao-r-t-er (4/5, 80.0%)
# --------------------------------------------------
# Cluster: naturally [length: 4], NED = 9.524%
# Phonetic variants and proportions:
# - n-ae-ch-er-ah-l-iy (2/4, 50.0%)
# - n-ae-ch-r-ah-l-iy (2/4, 50.0%)
# --------------------------------------------------
# Cluster: manager [length: 6], NED = 8.889%
# Phonetic variants and proportions:
# - m-ae-n-ih-jh-er (4/6, 66.7%)
# - m-ae-n-ah-jh-er (2/6, 33.3%)
# --------------------------------------------------
# Cluster: aunt [length: 3], NED = 22.222%
# Phonetic variants and proportions:
# - ae-n-t (2/3, 66.7%)
# - ao-n-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: forgot [length: 2], NED = 33.333%
# Phonetic variants and proportions:
# - f-ao-r-g-aa-t (1/2, 50.0%)
# - f-er-g-aa-t (1/2, 50.0%)
# --------------------------------------------------
# Cluster: nodded [length: 4], NED = 10.000%
# Phonetic variants and proportions:
# - n-aa-d-ih-d (3/4, 75.0%)
# - n-aa-d-ah-d (1/4, 25.0%)
# --------------------------------------------------
# Cluster: market [length: 4], NED = 8.333%
# Phonetic variants and proportions:
# - m-aa-r-k-ah-t (3/4, 75.0%)
# - m-aa-r-k-ih-t (1/4, 25.0%)
# --------------------------------------------------
# Cluster: flour [length: 12], NED = 13.258%
# Phonetic variants and proportions:
# - f-l-aw-r (5/12, 41.7%)
# - f-l-aw-er (7/12, 58.3%)
# --------------------------------------------------
# Cluster: americans [length: 4], NED = 5.556%
# Phonetic variants and proportions:
# - ah-m-eh-r-ah-k-ah-n-z (3/4, 75.0%)
# - ah-m-eh-r-ih-k-ah-n-z (1/4, 25.0%)
# --------------------------------------------------
# Cluster: splendid [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - s-p-l-eh-n-d-ah-d (1/3, 33.3%)
# - s-p-l-eh-n-d-ih-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: dishes [length: 5], NED = 12.000%
# Phonetic variants and proportions:
# - d-ih-sh-ah-z (2/5, 40.0%)
# - d-ih-sh-ih-z (3/5, 60.0%)
# --------------------------------------------------
# Cluster: classes [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - k-l-ae-s-ah-z (2/3, 66.7%)
# - k-l-ae-s-ih-z (1/3, 33.3%)
# --------------------------------------------------
# Cluster: communities [length: 2], NED = 10.000%
# Phonetic variants and proportions:
# - k-ah-m-y-uw-n-ah-t-iy-z (1/2, 50.0%)
# - k-ah-m-y-uw-n-ih-t-iy-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: privileges [length: 2], NED = 22.222%
# Phonetic variants and proportions:
# - p-r-ih-v-l-ih-jh-ih-z (1/2, 50.0%)
# - p-r-ih-v-l-ah-jh-ah-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: friendly [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - f-r-eh-n-l-iy (1/3, 33.3%)
# - f-r-eh-n-d-l-iy (2/3, 66.7%)
# --------------------------------------------------
# Cluster: seconds [length: 2], NED = 14.286%
# Phonetic variants and proportions:
# - s-eh-k-ah-n-z (1/2, 50.0%)
# - s-eh-k-ah-n-d-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: address [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - ae-d-r-eh-s (1/2, 50.0%)
# - ah-d-r-eh-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: saturday [length: 2], NED = 33.333%
# Phonetic variants and proportions:
# - s-ae-t-er-d-iy (1/2, 50.0%)
# - s-ae-t-ih-d-ey (1/2, 50.0%)
# --------------------------------------------------
# Cluster: news [length: 5], NED = 10.000%
# Phonetic variants and proportions:
# - n-y-uw-z (1/5, 20.0%)
# - n-uw-z (4/5, 80.0%)
# --------------------------------------------------
# Cluster: intervals [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - ih-n-t-er-v-ah-l-z (1/2, 50.0%)
# - ih-n-er-v-ah-l-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: appointed [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - ah-p-oy-n-t-ih-d (2/3, 66.7%)
# - ah-p-oy-n-t-ah-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: printed [length: 3], NED = 9.524%
# Phonetic variants and proportions:
# - p-r-ih-n-t-ah-d (1/3, 33.3%)
# - p-r-ih-n-t-ih-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: voyage [length: 2], NED = 25.000%
# Phonetic variants and proportions:
# - v-oy-ah-jh (1/2, 50.0%)
# - v-oy-ih-jh (1/2, 50.0%)
# --------------------------------------------------
# Cluster: haven't [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - hh-ae-v-ah-n-t (1/3, 33.3%)
# - hh-ae-v-ah-n (2/3, 66.7%)
# --------------------------------------------------
# Cluster: phrases [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - f-r-ey-z-ah-z (1/2, 50.0%)
# - f-r-ey-z-ih-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: bow [length: 3], NED = 33.333%
# Phonetic variants and proportions:
# - b-ow (2/3, 66.7%)
# - b-aw (1/3, 33.3%)
# --------------------------------------------------
# Cluster: refined [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - r-ih-f-ay-n-d (2/3, 66.7%)
# - r-ah-f-ay-n-d (1/3, 33.3%)
# --------------------------------------------------
# Cluster: cases [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - k-ey-s-ah-z (1/3, 33.3%)
# - k-ey-s-ih-z (2/3, 66.7%)
# --------------------------------------------------
# Cluster: decay [length: 3], NED = 16.667%
# Phonetic variants and proportions:
# - d-ih-k-ey (2/3, 66.7%)
# - d-ah-k-ey (1/3, 33.3%)
# --------------------------------------------------
# Cluster: discovery [length: 3], NED = 8.333%
# Phonetic variants and proportions:
# - d-ih-s-k-ah-v-r-iy (2/3, 66.7%)
# - d-ih-s-k-ah-v-er-iy (1/3, 33.3%)
# --------------------------------------------------
# Cluster: mounted [length: 3], NED = 11.111%
# Phonetic variants and proportions:
# - m-aw-n-t-ih-d (1/3, 33.3%)
# - m-aw-n-t-ah-d (2/3, 66.7%)
# --------------------------------------------------
# Cluster: brigade [length: 5], NED = 6.667%
# Phonetic variants and proportions:
# - b-r-ah-g-ey-d (4/5, 80.0%)
# - b-r-ih-g-ey-d (1/5, 20.0%)
# --------------------------------------------------
# Cluster: heroes [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - hh-ih-r-ow-z (1/2, 50.0%)
# - hh-iy-r-ow-z (1/2, 50.0%)
# --------------------------------------------------
# Cluster: wounded [length: 7], NED = 4.762%
# Phonetic variants and proportions:
# - w-uw-n-d-ih-d (6/7, 85.7%)
# - w-uw-n-d-ah-d (1/7, 14.3%)
# --------------------------------------------------
# Cluster: federal [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - f-eh-d-er-ah-l (1/2, 50.0%)
# - f-eh-d-r-ah-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: naturalists [length: 2], NED = 20.000%
# Phonetic variants and proportions:
# - n-ae-ch-r-ah-l-ih-s-t-s (1/2, 50.0%)
# - n-ae-ch-r-ah-l-ih-s (1/2, 50.0%)
# --------------------------------------------------
# Cluster: august [length: 3], NED = 13.333%
# Phonetic variants and proportions:
# - aa-g-ah-s-t (2/3, 66.7%)
# - ao-g-ah-s-t (1/3, 33.3%)
# --------------------------------------------------
# Cluster: africa [length: 3], NED = 22.222%
# Phonetic variants and proportions:
# - ae-f-er-k-ah (2/3, 66.7%)
# - ae-f-r-ah-k-ah (1/3, 33.3%)
# --------------------------------------------------
# Cluster: afflicted [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - ah-f-l-ih-k-t-ah-d (1/2, 50.0%)
# - ah-f-l-ih-k-t-ih-d (1/2, 50.0%)
# --------------------------------------------------
# Cluster: festival [length: 2], NED = 12.500%
# Phonetic variants and proportions:
# - f-eh-s-t-ih-v-ah-l (1/2, 50.0%)
# - f-eh-s-t-ah-v-ah-l (1/2, 50.0%)
# --------------------------------------------------
# Cluster: edition [length: 2], NED = 16.667%
# Phonetic variants and proportions:
# - ih-d-ih-sh-ah-n (1/2, 50.0%)
# - ah-d-ih-sh-ah-n (1/2, 50.0%)
# --------------------------------------------------
# Cluster: ferdinand [length: 5], NED = 5.000%
# Phonetic variants and proportions:
# - f-er-d-ih-n-ae-n (1/5, 20.0%)
# - f-er-d-ih-n-ae-n-d (4/5, 80.0%)
# --------------------------------------------------

# %%
def distance(seq1, seq2):
    print(f"Comparing '{seq1.split('-')}' and '{seq2.split("-")}'")
    return editdistance.eval(seq1.split("-"), seq2.split("-")) / max(len(seq1.split("-")), len(seq2.split("-")))

seq1 = "d-ih-m-ae-n-d-ih-d"
seq2 = "d-ih-m-ae-n-d-ah-d"
dist = distance(seq1, seq2)
print(f"Distance between '{seq1}' and '{seq2}': {dist*100:.3f}%")
# Out:
# Comparing '['d', 'ih', 'm', 'ae', 'n', 'd', 'ih', 'd']' and '['d', 'ih', 'm', 'ae', 'n', 'd', 'ah', 'd']'
# Distance between 'd-ih-m-ae-n-d-ih-d' and 'd-ih-m-ae-n-d-ah-d': 12.500%
